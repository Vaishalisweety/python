# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishalisweety/python/blob/main/Dataset_(02_09_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-fa1fa291-1626-4d6b-8a16-4447f0b08e89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa1fa291-1626-4d6b-8a16-4447f0b08e89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Students data.csv to Students data.csv

# %%
import pandas as pd
import io
 
stu= pd.read_csv(io.BytesIO(uploaded['Students data.csv']))
stu.head()
# Out:
#      ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# 0  1141     A    male     1  73.47       64         81         87          60
# 1  1142     A  female     1  71.22       57         50         51          51
# 2  1143     A  female     2  74.56       47         48         71          60
# 3  1144     A  female     1  72.89       46         72         38          60
# 4  1145     A  female     1  70.11       49         45         63          60
#
#    Probability  Measure  Functional_analysis from1 from2 from3  from4  y
# 0           74       71                   60     A     A     A      3  0
# 1           55       62                   61     B     A     A      2  0
# 2           61       68                   64     C     A     A      0  1
# 3           29       54                   51     D     A     A      0  0
# 4           66       66                   61     E     A     A      0  0

# %%
stu.isna().sum()
# Out:
# ID                     0
# class                  0
# gender                 0
# race                   0
# GPA                    0
# Algebra                0
# Calculus1              0
# Calculus2              0
# Statistics             0
# Probability            0
# Measure                0
# Functional_analysis    0
# from1                  0
# from2                  0
# from3                  0
# from4                  0
# y                      0
# dtype: int64

# %%
sns.jointplot(x='Statistics',y='Probability',data=stu)

# %%
stu.describe()
# Out:
#                 ID        race         GPA     Algebra   Calculus1  \
# count   105.000000  105.000000  105.000000  105.000000  105.000000
# mean   1193.000000    1.790476   82.957048   76.057143   71.961905
# std      30.454885    1.673867    6.053187   11.722618   12.197039
# min    1141.000000    1.000000   63.490000   46.000000   38.000000
# 25%    1167.000000    1.000000   79.340000   67.000000   64.000000
# 50%    1193.000000    1.000000   84.110000   76.000000   73.000000
# 75%    1219.000000    1.000000   87.300000   84.000000   80.000000
# max    1245.000000    7.000000   93.710000   98.000000  100.000000
#
#         Calculus2  Statistics  Probability     Measure  Functional_analysis  \
# count  105.000000  105.000000   105.000000  105.000000           105.000000
# mean    78.942857   85.133333    83.876190   80.761905            75.323810
# std     14.997326   10.269509    10.514363   10.296119            13.003324
# ...

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   105 non-null    int64
#  1   class                105 non-null    object
#  2   gender               105 non-null    object
#  3   race                 105 non-null    int64
#  4   GPA                  105 non-null    float64
#  5   Algebra              105 non-null    int64
#  6   Calculus1            105 non-null    int64
#  7   Calculus2            105 non-null    int64
#  8   Statistics           105 non-null    int64
#  9   Probability          105 non-null    int64
#  10  Measure              105 non-null    int64
#  11  Functional_analysis  105 non-null    int64
#  12  from1                105 non-null    object
#  13  from2                105 non-null    object
#  14  from3                105 non-null    object
# ...

# %%
stu.set_index('gender',inplace=True)
stu.head()
# Out:
#           ID class  race    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# gender
# male    1141     A     1  73.47       64         81         87          60
# female  1142     A     1  71.22       57         50         51          51
# female  1143     A     2  74.56       47         48         71          60
# female  1144     A     1  72.89       46         72         38          60
# female  1145     A     1  70.11       49         45         63          60
#
#         Probability  Measure  Functional_analysis from1 from2 from3  from4  y
# gender
# male             74       71                   60     A     A     A      3  0
# female           55       62                   61     B     A     A      2  0
# female           61       68                   64     C     A     A      0  1
# female           29       54                   51     D     A     A      0  0
# female           66       66                   61     E     A     A      0  0

# %%
sns.distplot(stu['GPA'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
stu.hist(layout=(20,20),figsize=(30,50))
plt.show()

# %%
sns.heatmap(stu.iloc[:,1:].corr(),annot = True)

# %%
sns.displot(stu['Probability'],kde=True,label='True')
plt.show()

# %%
sns.displot(stu['Statistics'],kde=True,label='True')
plt.axvline(stu['Statistics'].median(),color='green',ls='--')
plt.axvline(stu['Statistics'].mean(),color='red',ls='--')
plt.show()

# %%
sns.distplot(stu['race'],kde=True,label='True')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(stu['Algebra'],kde=True,label='True')
plt.show()

# %%
sns.distplot(stu['Measure'],kde=True,label='True')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(stu['Functional_analysis'],kde=True,label='True')
plt.show()

# %%
import pylab
import scipy.stats as stats
stats.probplot(stu['GPA'], dist="norm", plot=pylab)
pylab.show()

# %%
data_norm = np.random.normal(np.mean(stu['race']), np.std(stu['race']), len(stu))
data_norm
# Out:
# array([ 4.65196646e+00,  3.55805686e+00,  1.53905495e+00,  3.09795771e+00,
#         2.18284049e+00,  3.01375556e+00,  8.98357530e-01,  1.02474890e+00,
#         3.03755210e+00,  3.76286821e+00,  2.17662157e+00, -5.72019628e-01,
#         8.75851461e-01,  2.12994039e+00,  1.39281288e+00,  2.45985736e+00,
#         5.13887465e+00,  2.66197833e+00,  2.14488590e+00,  4.97203468e+00,
#         2.23479213e+00,  5.82963104e+00,  1.17055685e+00,  3.54525920e+00,
#         5.44481824e+00,  3.41823677e+00,  3.44090017e+00,  1.94217801e+00,
#        -2.98354213e+00,  3.56210110e+00, -5.85700234e-01,  1.74694641e+00,
#         3.48631752e-02, -1.18426986e-01,  2.24213809e+00,  4.80161964e-01,
#         2.13077449e+00,  2.56477828e+00, -5.14352527e-01,  4.01472202e-01,
#         2.55844731e-01,  1.48511744e+00,  1.15153489e+00,  1.65547642e+00,
#         1.22223543e+00,  2.02574245e+00,  5.53759350e-01,  5.18166447e-01,
# ...

# %%
sns.ecdfplot(stu['race'], c='blue')
sns.ecdfplot(data_norm, c='green')

# %%
from scipy.stats import normaltest

# %%
stu.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ID                     0.000000
# race                   2.094488
# GPA                   -0.912266
# Algebra               -0.200007
# Calculus1             -0.326777
# Calculus2             -1.223496
# Statistics            -1.177765
# Probability           -1.775706
# Measure               -0.375909
# Functional_analysis   -1.173611
# from4                  1.239738
# y                      0.579894
# dtype: float64

# %%
print( '\nNormal test for race :\n', normaltest(stu['race']))
# Out:
# Normal test for race :
#  NormaltestResult(statistic=51.946085475775206, pvalue=5.248689246199906e-12)

# %%
print( '\nNormal test for Statistics :\n', normaltest(stu['Statistics']))
# Out:
# Normal test for Statistics :
#  NormaltestResult(statistic=21.95409843146893, pvalue=1.7089450481633392e-05)

# %%
stu['GPA'].mean()
# Out:
# 82.95704761904761

# %%
stu['Statistics'].std()
# Out:
# 10.269509263485793

# %%
stu['Calculus1'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f%%')
plt.title("Distribution of Calculus1")
# Out:
# Text(0.5, 1.0, 'Distribution of Calculus1')

# %%
stu['Calculus2'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f%%')
plt.title("Distribution of Calculus2")
# Out:
# Text(0.5, 1.0, 'Distribution of Calculus2')

# %%
stu['ID'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f%%')
plt.title("Distribution of ID")
# Out:
# Text(0.5, 1.0, 'Distribution of ID')

# %%
sns.scatterplot(data=stu,x='Probability',y='race',hue='GPA')

# %%
sns.scatterplot(data=stu,x='GPA',y='race',hue='Probability')
plt.grid()
plt.show()

# %%
sns.lmplot(x="Probability",y="Statistics",data=stu)
