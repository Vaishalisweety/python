# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishalisweety/python/blob/main/Dataset_(02_09_22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
data = np.random.normal(170, 10, 250)

# %%
mu, std = norm.fit(data)

# %%
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit Values: {:.2f} and {:.2f}".format(mu, std)
plt.title(title)
  
plt.show()

# %%
import statistics
x_axis = np.arange(-30, 30, 0.1)
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis)

# %%
plt.plot(x_axis, norm.pdf(x_axis, mean, sd))
plt.show()
